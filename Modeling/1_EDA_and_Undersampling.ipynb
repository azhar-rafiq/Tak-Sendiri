# %%
import pandas as pd

# %%
df = pd.read_csv('Dataset/0a_fixed_data.csv')

# %%
df["label"].value_counts()
# Out:
# 0    6914
# 1    1101
# Name: label, dtype: int64

# %%
temp = df[df["label"]==0]
temp = temp.iloc[:1101, :]
temp.shape
# Out:
# (1101, 2)

# %%
df = pd.concat([temp, df[df["label"]==1]], axis=0)
df.shape
# Out:
# (2202, 2)

# %%
df = df.sample(frac = 1)

# %%
df
# Out:
#                                                    text  label
# 1080  ngeliat anak dream apalagi jisung yg seumuran ...      0
# 586                      Kok rada-rada cemas ya saya :(      0
# 547       Ya Allah gue ga tau ko hati gue gelisah ya :(      0
# 594   ah i see, kayanya mual disebabkan terlalu cema...      0
# 912                               apa aku jual tutor lg      0
# 1005                        Pokoke kudu misuh ben plong      0
# 398                                Gelisah mulu napasii      0
# 7314  2 Minggu ketika perasaan merahasiakan kabarnya...      1
# 906   LIN COMO TW AMP ERED LO MEJOT DWL MUNDOOOOOOO ...      0
# 89    Lagi gelisah. Semoga yg disana baik2 saja yah....      0
# 474   Tidak usah terlalu cemas, ceritamu ditulis ole...      0
# 438   Rasa cemas yg kegini ni yg gue gak suka😭 .Tiba...      0
# 174   bbrp hari ini gue kayaknya ga baik baik aja sa...      0
# 7291  separah inilah aku yang tak mengerti bahwa ada...      1
# ...

# %%
df["label"].hist()
# Out:
# <AxesSubplot:>

# %%
# df.to_csv("0a_fixed_data_balanced.csv", index=False)

# %%
def f(x):
    print("halo")
    return x ** 2

# %%
print(f(10))
# Out:
# halo
# 100
